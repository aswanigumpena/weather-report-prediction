# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Weather.csv')

# %%
df
# Out:
#           STA        Date Precip  WindGustSpd    MaxTemp    MinTemp  \
# 0       10001    7/1/1942  1.016          NaN  25.555556  22.222222
# 1       10001    7/2/1942      0          NaN  28.888889  21.666667
# 2       10001    7/3/1942   2.54          NaN  26.111111  22.222222
# 3       10001    7/4/1942   2.54          NaN  26.666667  22.222222
# 4       10001    7/5/1942      0          NaN  26.666667  21.666667
# ...       ...         ...    ...          ...        ...        ...
# 119035  82506  12/27/1945      0          NaN  28.333333  18.333333
# 119036  82506  12/28/1945  9.906          NaN  29.444444  18.333333
# 119037  82506  12/29/1945      0          NaN  28.333333  18.333333
# 119038  82506  12/30/1945      0          NaN  28.333333  18.333333
# 119039  82506  12/31/1945      0          NaN  29.444444  17.222222
#
#          MeanTemp Snowfall PoorWeather  YR  ...  FT  FB FTI  PGT  TSHDSBRSGF  \
# 0       23.888889      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN
# 1       25.555556      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN
# 2       24.444444      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN
# 3       24.444444      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN
# 4       24.444444      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN
# ...           ...      ...         ...  ..  ...  ..  ..  ..  ...         ...
# 119035  23.333333      0.0         NaN  45  ... NaN NaN NaN  NaN         NaN
# 119036  23.888889      0.0         1.0  45  ... NaN NaN NaN  NaN         1.0
# 119037  23.333333      0.0         1.0  45  ... NaN NaN NaN  NaN         1.0
# 119038  23.333333      0.0         NaN  45  ... NaN NaN NaN  NaN         NaN
# 119039  23.333333      0.0         NaN  45  ... NaN NaN NaN  NaN         NaN
#
#         SD3  RHX  RHN RVG  WTE
# 0       NaN  NaN  NaN NaN  NaN
# 1       NaN  NaN  NaN NaN  NaN
# 2       NaN  NaN  NaN NaN  NaN
# 3       NaN  NaN  NaN NaN  NaN
# 4       NaN  NaN  NaN NaN  NaN
# ...     ...  ...  ...  ..  ...
# 119035  NaN  NaN  NaN NaN  NaN
# 119036  NaN  NaN  NaN NaN  NaN
# 119037  NaN  NaN  NaN NaN  NaN
# 119038  NaN  NaN  NaN NaN  NaN
# 119039  NaN  NaN  NaN NaN  NaN
#
# [119040 rows x 30 columns]

# %%
df.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  7/1/1942  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  7/2/1942      0          NaN  28.888889  21.666667  25.555556
# 2  10001  7/3/1942   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  7/4/1942   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  7/5/1942      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FT  FB FTI  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# 4 NaN  NaN
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 30 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STA          119040 non-null  int64
#  1   Date         119040 non-null  object
#  2   Precip       119040 non-null  object
#  3   WindGustSpd  532 non-null     float64
#  4   MaxTemp      119040 non-null  float64
#  5   MinTemp      119040 non-null  float64
#  6   MeanTemp     119040 non-null  float64
#  7   Snowfall     117877 non-null  object
#  8   PoorWeather  34237 non-null   object
#  9   YR           119040 non-null  int64
#  10  MO           119040 non-null  int64
#  11  DA           119040 non-null  int64
#  12  PRCP         117108 non-null  object
#  13  DR           533 non-null     float64
#  14  SPD          532 non-null     float64
#  15  MAX          118566 non-null  float64
#  16  MIN          118572 non-null  float64
#  17  MEA          118542 non-null  float64
#  18  SNF          117877 non-null  object
#  19  SND          5563 non-null    float64
#  20  FT           0 non-null       float64
#  21  FB           0 non-null       float64
#  22  FTI          0 non-null       float64
#  23  PGT          525 non-null     float64
#  24  TSHDSBRSGF   34237 non-null   object
#  25  SD3          0 non-null       float64
#  26  RHX          0 non-null       float64
#  27  RHN          0 non-null       float64
#  28  RVG          0 non-null       float64
#  29  WTE          0 non-null       float64
# dtypes: float64(19), int64(4), object(7)
# memory usage: 27.2+ MB

# %%
df.describe().T
# Out:
#                 count          mean           std           min           25%  \
# STA          119040.0  29659.435795  20953.209402  10001.000000  11801.000000
# WindGustSpd     532.0     37.774534     10.297808     18.520000     29.632000
# MaxTemp      119040.0     27.045111      8.717817    -33.333333     25.555556
# MinTemp      119040.0     17.789511      8.334572    -38.333333     15.000000
# MeanTemp     119040.0     22.411631      8.297982    -35.555556     20.555556
# YR           119040.0     43.805284      1.136718     40.000000     43.000000
# MO           119040.0      6.726016      3.425561      1.000000      4.000000
# DA           119040.0     15.797530      8.794541      1.000000      8.000000
# DR              533.0     26.998124     15.221732      2.000000     11.000000
# SPD             532.0     20.396617      5.560371     10.000000     16.000000
# MAX          118566.0     81.003745     14.869361    -28.000000     78.000000
# MIN          118572.0     64.273808     14.481498    -37.000000     59.000000
# MEA          118542.0     72.644843     14.211082    -32.000000     69.000000
# SND            5563.0      0.000000      0.000000      0.000000      0.000000
# FT                0.0           NaN           NaN           NaN           NaN
# FB                0.0           NaN           NaN           NaN           NaN
# FTI               0.0           NaN           NaN           NaN           NaN
# PGT             525.0     12.085333      5.731328      0.000000      8.500000
# SD3               0.0           NaN           NaN           NaN           NaN
# RHX               0.0           NaN           NaN           NaN           NaN
# RHN               0.0           NaN           NaN           NaN           NaN
# RVG               0.0           NaN           NaN           NaN           NaN
# WTE               0.0           NaN           NaN           NaN           NaN
#
#                       50%           75%           max
# STA          22508.000000  33501.000000  82506.000000
# WindGustSpd     37.040000     43.059000     75.932000
# MaxTemp         29.444444     31.666667     50.000000
# MinTemp         21.111111     23.333333     34.444444
# MeanTemp        25.555556     27.222222     40.000000
# YR              44.000000     45.000000     45.000000
# MO               7.000000     10.000000     12.000000
# DA              16.000000     23.000000     31.000000
# DR              32.000000     34.000000     78.000000
# SPD             20.000000     23.250000     41.000000
# MAX             85.000000     89.000000    122.000000
# MIN             70.000000     74.000000     94.000000
# MEA             78.000000     81.000000    104.000000
# SND              0.000000      0.000000      0.000000
# FT                    NaN           NaN           NaN
# FB                    NaN           NaN           NaN
# FTI                   NaN           NaN           NaN
# PGT             11.600000     15.000000     23.900000
# SD3                   NaN           NaN           NaN
# RHX                   NaN           NaN           NaN
# RHN                   NaN           NaN           NaN
# RVG                   NaN           NaN           NaN
# WTE                   NaN           NaN           NaN

# %%
df.corr()
# Out:
#                   STA  WindGustSpd   MaxTemp   MinTemp  MeanTemp        YR  \
# STA          1.000000    -0.549603  0.092371  0.059319  0.078112  0.121408
# WindGustSpd -0.549603     1.000000 -0.124238  0.311690  0.197264       NaN
# MaxTemp      0.092371    -0.124238  1.000000  0.878384  0.969048  0.039585
# MinTemp      0.059319     0.311690  0.878384  1.000000  0.965425 -0.020733
# MeanTemp     0.078112     0.197264  0.969048  0.965425  1.000000  0.010681
# YR           0.121408          NaN  0.039585 -0.020733  0.010681  1.000000
# MO          -0.008592     0.149525  0.031346  0.069078  0.050769 -0.144360
# DA           0.000903     0.002081 -0.005130 -0.002576 -0.004153 -0.011196
# DR          -0.832958     0.351027  0.011875  0.525019  0.407395       NaN
# SPD         -0.549603     1.000000 -0.124238  0.311690  0.197264       NaN
# MAX          0.083943    -0.124238  1.000000  0.872096  0.965838  0.013986
# MIN          0.050807     0.311690  0.870594  1.000000  0.963279 -0.043323
# MEA          0.069775     0.197264  0.968247  0.966441  1.000000 -0.014723
# SND               NaN          NaN       NaN       NaN       NaN       NaN
# FT                NaN          NaN       NaN       NaN       NaN       NaN
# FB                NaN          NaN       NaN       NaN       NaN       NaN
# FTI               NaN          NaN       NaN       NaN       NaN       NaN
# PGT         -0.139697     0.063630 -0.077015  0.007828 -0.022448       NaN
# SD3               NaN          NaN       NaN       NaN       NaN       NaN
# RHX               NaN          NaN       NaN       NaN       NaN       NaN
# RHN               NaN          NaN       NaN       NaN       NaN       NaN
# RVG               NaN          NaN       NaN       NaN       NaN       NaN
# WTE               NaN          NaN       NaN       NaN       NaN       NaN
#
#                    MO        DA        DR       SPD  ...  SND  FT  FB  FTI  \
# STA         -0.008592  0.000903 -0.832958 -0.549603  ...  NaN NaN NaN  NaN
# WindGustSpd  0.149525  0.002081  0.351027  1.000000  ...  NaN NaN NaN  NaN
# MaxTemp      0.031346 -0.005130  0.011875 -0.124238  ...  NaN NaN NaN  NaN
# MinTemp      0.069078 -0.002576  0.525019  0.311690  ...  NaN NaN NaN  NaN
# MeanTemp     0.050769 -0.004153  0.407395  0.197264  ...  NaN NaN NaN  NaN
# YR          -0.144360 -0.011196       NaN       NaN  ...  NaN NaN NaN  NaN
# MO           1.000000  0.006563  0.655035  0.149525  ...  NaN NaN NaN  NaN
# DA           0.006563  1.000000  0.012000  0.002081  ...  NaN NaN NaN  NaN
# DR           0.655035  0.012000  1.000000  0.351027  ...  NaN NaN NaN  NaN
# SPD          0.149525  0.002081  0.351027  1.000000  ...  NaN NaN NaN  NaN
# MAX          0.034329 -0.003299  0.011875 -0.124238  ...  NaN NaN NaN  NaN
# MIN          0.072453 -0.000739  0.525019  0.311690  ...  NaN NaN NaN  NaN
# MEA          0.054847 -0.002094  0.407395  0.197264  ...  NaN NaN NaN  NaN
# SND               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# FT                NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# FB                NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# FTI               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# PGT          0.106800  0.001121  0.099215  0.063630  ...  NaN NaN NaN  NaN
# SD3               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# RHX               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# RHN               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# RVG               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
# WTE               NaN       NaN       NaN       NaN  ...  NaN NaN NaN  NaN
#
#                   PGT  SD3  RHX  RHN  RVG  WTE
# STA         -0.139697  NaN  NaN  NaN  NaN  NaN
# WindGustSpd  0.063630  NaN  NaN  NaN  NaN  NaN
# MaxTemp     -0.077015  NaN  NaN  NaN  NaN  NaN
# MinTemp      0.007828  NaN  NaN  NaN  NaN  NaN
# MeanTemp    -0.022448  NaN  NaN  NaN  NaN  NaN
# YR                NaN  NaN  NaN  NaN  NaN  NaN
# MO           0.106800  NaN  NaN  NaN  NaN  NaN
# DA           0.001121  NaN  NaN  NaN  NaN  NaN
# DR           0.099215  NaN  NaN  NaN  NaN  NaN
# SPD          0.063630  NaN  NaN  NaN  NaN  NaN
# MAX         -0.077015  NaN  NaN  NaN  NaN  NaN
# MIN          0.007828  NaN  NaN  NaN  NaN  NaN
# MEA         -0.022448  NaN  NaN  NaN  NaN  NaN
# SND               NaN  NaN  NaN  NaN  NaN  NaN
# FT                NaN  NaN  NaN  NaN  NaN  NaN
# FB                NaN  NaN  NaN  NaN  NaN  NaN
# FTI               NaN  NaN  NaN  NaN  NaN  NaN
# PGT          1.000000  NaN  NaN  NaN  NaN  NaN
# SD3               NaN  NaN  NaN  NaN  NaN  NaN
# RHX               NaN  NaN  NaN  NaN  NaN  NaN
# RHN               NaN  NaN  NaN  NaN  NaN  NaN
# RVG               NaN  NaN  NaN  NaN  NaN  NaN
# WTE               NaN  NaN  NaN  NaN  NaN  NaN
#
# [23 rows x 23 columns]

# %%
df.isna().any()
# Out:
# STA            False
# Date           False
# Precip         False
# WindGustSpd     True
# MaxTemp        False
# MinTemp        False
# MeanTemp       False
# Snowfall        True
# PoorWeather     True
# YR             False
# MO             False
# DA             False
# PRCP            True
# DR              True
# SPD             True
# MAX             True
# MIN             True
# MEA             True
# SNF             True
# SND             True
# FT              True
# FB              True
# FTI             True
# PGT             True
# TSHDSBRSGF      True
# SD3             True
# RHX             True
# RHN             True
# RVG             True
# WTE             True
# dtype: bool

# %%
#problem statment:estimate Max temperature
df['MaxTemp'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119035    False
# 119036    False
# 119037    False
# 119038    False
# 119039    False
# Name: MaxTemp, Length: 119040, dtype: bool

# %%
y=df[['MaxTemp']]

# %%
y.isna().apply(pd.value_counts).T
# Out:
#           False
# MaxTemp  119040

# %%
y.isna().apply(pd.value_counts).T
# Out:
#           False
# MaxTemp  119040

# %%
x=df[['MinTemp']]

# %%
x.isna().apply(pd.value_counts).T
# Out:
#           False
# MinTemp  119040

# %%
x.head()
# Out:
#      MinTemp
# 0  22.222222
# 1  21.666667
# 2  22.222222
# 3  22.222222
# 4  21.666667

# %%
y.head()
# Out:
#      MaxTemp
# 0  25.555556
# 1  28.888889
# 2  26.111111
# 3  26.666667
# 4  26.666667

# %%
x.shape
# Out:
# (119040, 1)

# %%
y.shape
# Out:
# (119040, 1)

# %%
#import train test split
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=1)

# %%
print(x_train.shape)
# Out:
# (83328, 1)

# %%
x_test.shape
# Out:
# (35712, 1)

# %%
y_train.shape
# Out:
# (83328, 1)

# %%
y_test.shape
# Out:
# (35712, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[20.88972865],
#        [28.56451499],
#        [31.63442954],
#        ...,
#        [31.12277711],
#        [28.56451499],
#        [31.12277711]])

# %%
y_pred.shape
# Out:
# (35712, 1)

# %%
#y_test=y_test.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)
y_test
# Out:
# array([[29.44444444],
#        [32.77777778],
#        [37.22222222],
#        ...,
#        [32.77777778],
#        [30.        ],
#        [28.88888889]])

# %%
x_test
# Out:
#           MinTemp
# 62234   11.111111
# 28328   19.444444
# 62139   22.777778
# 37166   21.666667
# 10655   23.333333
# ...           ...
# 88900   11.666667
# 108507  21.111111
# 31998   22.222222
# 56907   19.444444
# 63891   22.222222
#
# [35712 rows x 1 columns]

# %%
x_test.shape
# Out:
# (35712, 1)

# %%
y_test
# Out:
#           MaxTemp
# 62234   29.444444
# 28328   32.777778
# 62139   37.222222
# 37166   33.333333
# 10655   30.000000
# ...           ...
# 88900   37.222222
# 108507  27.222222
# 31998   32.777778
# 56907   30.000000
# 63891   28.888889
#
# [35712 rows x 1 columns]

# %%
m=model.coef_

# %%
m
# Out:
# array([[0.92097436]])

# %%
c=model.intercept_

# %%
c
# Out:
# array([10.65668019])

# %%
df_comp=pd.DataFrame({'Actual_MaxTemp':y_test.flatten(),'predicted_MaxTemp':y_pred.flatten()})

# %%
df_comp
# Out:
#        Actual_MaxTemp  predicted_MaxTemp
# 0           29.444444          20.889729
# 1           32.777778          28.564515
# 2           37.222222          31.634430
# 3           33.333333          30.611125
# 4           30.000000          32.146082
# ...               ...                ...
# 35707       37.222222          21.401381
# 35708       27.222222          30.099472
# 35709       32.777778          31.122777
# 35710       30.000000          28.564515
# 35711       28.888889          31.122777
#
# [35712 rows x 2 columns]

# %%
df_comp.to_csv('Predict.csv')

# %%
model.score(x_test,y_test)*100
# Out:
# 76.58019339654669

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test,y_pred)*100
# Out:
# 76.58019339654669

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 17.560811008066533

# %%
#Calculate Adj. R2_Score from scratch
(1-(1-model.score(x_test,y_test))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))*100
# Out:
# 76.5795375632618

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(y_test)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(y_pred)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(y_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(y_pred)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(y_test,y_pred)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(y_test,y_pred,color='red')
plt.plot(y_test,y_pred,color='blue')

# %%
plt.scatter(y_test,y_pred,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.xlabel('MinTemp')
plt.ylabel('MaxTemp')
plt.title("Bestfitline for predicted values")
plt.show()
